# %%
try:
  # %tensorflow_version 2.x
except:
  pass
# Out:
# TensorFlow 2.x selected.

# %%
# !pip install tensorflow==2.0.0-rc0
# !pip install plotly
# !pip install cufflinks
# Out:
# Requirement already satisfied: tensorflow==2.0.0-rc0 in /tensorflow-2.0.0-rc0/python3.6 (2.0.0rc0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.17.2)
# Requirement already satisfied: wheel>=0.26 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (0.33.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (0.1.7)
# Requirement already satisfied: keras-applications>=1.0.8 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (0.8.0)
# Requirement already satisfied: astor>=0.6.0 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (0.8.0)
# Requirement already satisfied: six>=1.10.0 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.12.0)
# Requirement already satisfied: gast>=0.2.0 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (0.3.1)
# Requirement already satisfied: protobuf>=3.6.1 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (3.9.1)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019080602,>=1.14.0.dev2019080601 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.14.0.dev2019080601)
# Requirement already satisfied: termcolor>=1.1.0 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.23.0)
# Requirement already satisfied: tb-nightly<1.15.0a20190807,>=1.15.0a20190806 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.15.0a20190806)
# Requirement already satisfied: opt-einsum>=2.3.2 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (3.0.1)
# Requirement already satisfied: wrapt>=1.11.1 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.11.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /tensorflow-2.0.0-rc0/python3.6 (from tensorflow==2.0.0-rc0) (1.1.0)
# Requirement already satisfied: h5py in /tensorflow-2.0.0-rc0/python3.6 (from keras-applications>=1.0.8->tensorflow==2.0.0-rc0) (2.10.0)
# Requirement already satisfied: setuptools in /tensorflow-2.0.0-rc0/python3.6 (from protobuf>=3.6.1->tensorflow==2.0.0-rc0) (41.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /tensorflow-2.0.0-rc0/python3.6 (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc0) (0.15.6)
# Requirement already satisfied: markdown>=2.6.8 in /tensorflow-2.0.0-rc0/python3.6 (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0.0-rc0) (3.1.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (3.10.0)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly) (4.4.0)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly) (4.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly) (2018.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly) (2.21.0)
# Requirement already satisfied: six in /tensorflow-2.0.0-rc0/python3.6 (from plotly) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (4.5.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly) (1.24.3)
# Collecting cufflinks
#   Downloading https://files.pythonhosted.org/packages/5e/5a/db3d6523ee870ecc229008b209b6b21231397302de34f9c446929a41f027/cufflinks-0.16.tar.gz (81kB)
#      |████████████████████████████████| 81kB 2.7MB/s
# Requirement already satisfied: numpy>=1.9.2 in /tensorflow-2.0.0-rc0/python3.6 (from cufflinks) (1.17.2)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (0.24.2)
# Requirement already satisfied: plotly<4.0.0a0,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (3.10.0)
# Requirement already satisfied: six>=1.9.0 in /tensorflow-2.0.0-rc0/python3.6 (from cufflinks) (1.12.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading https://files.pythonhosted.org/packages/9a/53/f696e4480b1d1de3b1523991dea71cf417c8b19fe70c704da164f3f90972/colorlover-0.3.0-py3-none-any.whl
# Requirement already satisfied: setuptools>=34.4.1 in /tensorflow-2.0.0-rc0/python3.6 (from cufflinks) (41.2.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (5.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks) (7.5.1)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks) (2.5.3)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (2.21.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly<4.0.0a0,>=3.0.0->cufflinks) (1.3.3)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (1.0.16)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (4.7.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (2.1.3)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks) (4.3.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (4.6.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly<4.0.0a0,>=3.0.0->cufflinks) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly<4.0.0a0,>=3.0.0->cufflinks) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly<4.0.0a0,>=3.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly<4.0.0a0,>=3.0.0->cufflinks) (2.8)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->cufflinks) (0.6.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (4.5.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.2.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (17.0.0)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.10.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (setup.py) ... done
#   Created wheel for cufflinks: filename=cufflinks-0.16-cp36-none-any.whl size=67603 sha256=e4660522d8f45e09667cb7936a5b38de56805538c037b0fde3783a85773df3db
#   Stored in directory: /root/.cache/pip/wheels/8d/5a/6f/c97d47dc901071611809eb61aaa477d50a60692dc764dca622
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.16

# %%
# !pip install plotly==3.1.0
# Out:
# Collecting plotly==3.1.0
#   Downloading https://files.pythonhosted.org/packages/8a/e3/e1baab5b000158966d2c70ceebbdf2cce8a665fb77445aa5ab2dc4fb05a5/plotly-3.1.0.tar.gz (30.3MB)
#      |████████████████████████████████| 30.3MB 25.5MB/s
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly==3.1.0) (4.4.0)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly==3.1.0) (4.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly==3.1.0) (2018.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly==3.1.0) (2.21.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly==3.1.0) (1.3.3)
# Requirement already satisfied: six in /tensorflow-2.0.0-rc0/python3.6 (from plotly==3.1.0) (1.12.0)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.1.0) (4.3.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.1.0) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.1.0) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.1.0) (4.5.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.1.0) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.1.0) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.1.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.1.0) (2019.6.16)
# Building wheels for collected packages: plotly
#   Building wheel for plotly (setup.py) ... done
#   Created wheel for plotly: filename=plotly-3.1.0-cp36-none-any.whl size=36867540 sha256=ca3403bef9939334633f3a95525824bea13fe870cfcc62d284d2208708cee72c
#   Stored in directory: /root/.cache/pip/wheels/9f/8c/a4/a1a26a9a0ac42d852e0fb4b0ba021cc6b881aab075d03e903b
# Successfully built plotly
# Installing collected packages: plotly
# Successfully installed plotly-3.1.0

# %%
# %%time
from __future__ import absolute_import, division, unicode_literals, print_function
# %reload_ext autoreload
# %autoreload 2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import *
from tensorflow.keras.datasets import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.preprocessing.image import *
tf.__version__

from sklearn.model_selection import *
from sklearn.metrics import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
import seaborn as sns
sns.set(rc={'figure.figsize':(12,10)})

import os
import gc
gc.enable()
import math
import glob
import random
import subprocess

import warnings
warnings.filterwarnings("ignore")

print(os.listdir())
print("Done.!")
# Out:
# ['.config', 'sample_data']
# Done.!
# CPU times: user 1.77 s, sys: 166 ms, total: 1.93 s
# Wall time: 1.95 s

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(20,20))
for i in range(200):
  plt.subplot(20,10,i+1)
  plt.imshow(X_train[i,:,:], cmap="gray")
  plt.xticks([])
  plt.yticks([])
  plt.grid(True)
  plt.xlabel(y_train[i],fontsize=15)
  plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.utils import *

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

X_train, X_test = X_train/255.0, X_test/255.0

y_train_copy = pd.DataFrame(y_train, columns=["y_true"])
y_train_copy["y_true"].value_counts().plot(kind="barh")

y_train, y_test = to_categorical(y_train), to_categorical(y_test)

X_train = X_train.reshape(-1,28,28,1)
X_test = X_test.reshape(-1,28,28,1)

X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.2,random_state=0)

# %%
model_name = 'model_custom_base.h5'
early_stopping = EarlyStopping(monitor="val_loss",verbose=1,patience=5,restore_best_weights=True)
checkpoint = ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
reduce_lr_on_plateau = ReduceLROnPlateau(monitor = 'val_loss',patience = 3, factor=0.5, verbose=1)

# %%
def custom_nn():
  model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
  tf.keras.layers.Dense(128, activation='relu', kernel_initializer="glorot_uniform"),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(64, activation='relu', kernel_initializer="glorot_uniform"),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(10, activation='softmax')
  ])

  model.compile(Adam(0.001), "categorical_crossentropy", ["accuracy"])

  model.summary()

  return model

# %%
model = custom_nn()

datagen = ImageDataGenerator(featurewise_center=False,  
                               samplewise_center=False,  
                               featurewise_std_normalization=False,  
                               samplewise_std_normalization=False,  
                               zca_whitening=False,  
                               rotation_range=10,  
                               zoom_range = 0.1, 
                               width_shift_range=0.1,  
                               height_shift_range=0.1,  
                               horizontal_flip=False,  
                               vertical_flip=False)

datagen.fit(X_train)

history = model.fit_generator(datagen.flow(X_train, 
                      y_train,
                      batch_size=512),
                      epochs=40,  
                      steps_per_epoch=X_train.shape[0] // 128, 
                      validation_data = (X_val,y_val),
                      verbose=2,
                      callbacks = [early_stopping, reduce_lr_on_plateau, checkpoint])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128)               512
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 64)                256
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                650
# =================================================================
# Total params: 110,154
# Trainable params: 109,770
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/40
#
# Epoch 00001: val_loss did not improve from 0.44709
# 375/375 - 83s - loss: 0.8134 - accuracy: 0.7015 - val_loss: 0.5399 - val_accuracy: 0.8025
# Epoch 2/40
#
# Epoch 00002: val_loss did not improve from 0.44709
# 375/375 - 83s - loss: 0.6327 - accuracy: 0.7623 - val_loss: 0.4737 - val_accuracy: 0.8256
# Epoch 3/40
#
# Epoch 00003: val_loss did not improve from 0.44709
# 375/375 - 83s - loss: 0.5941 - accuracy: 0.7766 - val_loss: 0.4587 - val_accuracy: 0.8192
# Epoch 4/40
#
# Epoch 00004: val_loss improved from 0.44709 to 0.44536, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.5713 - accuracy: 0.7853 - val_loss: 0.4454 - val_accuracy: 0.8303
# Epoch 5/40
#
# Epoch 00005: val_loss improved from 0.44536 to 0.44123, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.5565 - accuracy: 0.7904 - val_loss: 0.4412 - val_accuracy: 0.8289
# Epoch 6/40
#
# Epoch 00006: val_loss improved from 0.44123 to 0.42128, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.5443 - accuracy: 0.7946 - val_loss: 0.4213 - val_accuracy: 0.8391
# Epoch 7/40
#
# Epoch 00007: val_loss improved from 0.42128 to 0.41987, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.5334 - accuracy: 0.7979 - val_loss: 0.4199 - val_accuracy: 0.8425
# Epoch 8/40
#
# Epoch 00008: val_loss did not improve from 0.41987
# 375/375 - 84s - loss: 0.5275 - accuracy: 0.8013 - val_loss: 0.4202 - val_accuracy: 0.8393
# Epoch 9/40
#
# Epoch 00009: val_loss improved from 0.41987 to 0.40997, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.5246 - accuracy: 0.8022 - val_loss: 0.4100 - val_accuracy: 0.8429
# Epoch 10/40
#
# Epoch 00010: val_loss improved from 0.40997 to 0.40679, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.5158 - accuracy: 0.8056 - val_loss: 0.4068 - val_accuracy: 0.8495
# Epoch 11/40
#
# Epoch 00011: val_loss improved from 0.40679 to 0.40250, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.5126 - accuracy: 0.8079 - val_loss: 0.4025 - val_accuracy: 0.8462
# Epoch 12/40
#
# Epoch 00012: val_loss improved from 0.40250 to 0.40242, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.5103 - accuracy: 0.8079 - val_loss: 0.4024 - val_accuracy: 0.8474
# Epoch 13/40
#
# Epoch 00013: val_loss did not improve from 0.40242
# 375/375 - 84s - loss: 0.5071 - accuracy: 0.8096 - val_loss: 0.4030 - val_accuracy: 0.8495
# Epoch 14/40
#
# Epoch 00014: val_loss improved from 0.40242 to 0.39629, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.5028 - accuracy: 0.8109 - val_loss: 0.3963 - val_accuracy: 0.8508
# Epoch 15/40
#
# Epoch 00015: val_loss improved from 0.39629 to 0.38792, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.4998 - accuracy: 0.8114 - val_loss: 0.3879 - val_accuracy: 0.8518
# Epoch 16/40
#
# Epoch 00016: val_loss improved from 0.38792 to 0.37868, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.4954 - accuracy: 0.8130 - val_loss: 0.3787 - val_accuracy: 0.8565
# Epoch 17/40
#
# Epoch 00017: val_loss did not improve from 0.37868
# 375/375 - 83s - loss: 0.4943 - accuracy: 0.8135 - val_loss: 0.3907 - val_accuracy: 0.8491
# Epoch 18/40
#
# Epoch 00018: val_loss did not improve from 0.37868
# 375/375 - 83s - loss: 0.4920 - accuracy: 0.8150 - val_loss: 0.3873 - val_accuracy: 0.8566
# Epoch 19/40
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.37868
# 375/375 - 83s - loss: 0.4912 - accuracy: 0.8144 - val_loss: 0.3983 - val_accuracy: 0.8468
# Epoch 20/40
#
# Epoch 00020: val_loss improved from 0.37868 to 0.37358, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.4777 - accuracy: 0.8197 - val_loss: 0.3736 - val_accuracy: 0.8620
# Epoch 21/40
#
# Epoch 00021: val_loss improved from 0.37358 to 0.37097, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.4747 - accuracy: 0.8212 - val_loss: 0.3710 - val_accuracy: 0.8643
# Epoch 22/40
#
# Epoch 00022: val_loss did not improve from 0.37097
# 375/375 - 83s - loss: 0.4742 - accuracy: 0.8219 - val_loss: 0.3808 - val_accuracy: 0.8600
# Epoch 23/40
#
# Epoch 00023: val_loss did not improve from 0.37097
# 375/375 - 83s - loss: 0.4752 - accuracy: 0.8227 - val_loss: 0.3744 - val_accuracy: 0.8619
# Epoch 24/40
#
# Epoch 00024: val_loss improved from 0.37097 to 0.36837, saving model to model_custom_base.h5
# 375/375 - 82s - loss: 0.4720 - accuracy: 0.8218 - val_loss: 0.3684 - val_accuracy: 0.8643
# Epoch 25/40
#
# Epoch 00025: val_loss improved from 0.36837 to 0.36670, saving model to model_custom_base.h5
# 375/375 - 82s - loss: 0.4709 - accuracy: 0.8224 - val_loss: 0.3667 - val_accuracy: 0.8631
# Epoch 26/40
#
# Epoch 00026: val_loss improved from 0.36670 to 0.36614, saving model to model_custom_base.h5
# 375/375 - 84s - loss: 0.4703 - accuracy: 0.8227 - val_loss: 0.3661 - val_accuracy: 0.8640
# Epoch 27/40
#
# Epoch 00027: val_loss did not improve from 0.36614
# 375/375 - 83s - loss: 0.4706 - accuracy: 0.8233 - val_loss: 0.3720 - val_accuracy: 0.8627
# Epoch 28/40
#
# Epoch 00028: val_loss did not improve from 0.36614
# 375/375 - 83s - loss: 0.4669 - accuracy: 0.8246 - val_loss: 0.3766 - val_accuracy: 0.8600
# Epoch 29/40
#
# Epoch 00029: val_loss improved from 0.36614 to 0.35980, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.4677 - accuracy: 0.8242 - val_loss: 0.3598 - val_accuracy: 0.8698
# Epoch 30/40
#
# Epoch 00030: val_loss did not improve from 0.35980
# 375/375 - 83s - loss: 0.4654 - accuracy: 0.8244 - val_loss: 0.3658 - val_accuracy: 0.8636
# Epoch 31/40
#
# Epoch 00031: val_loss did not improve from 0.35980
# 375/375 - 83s - loss: 0.4644 - accuracy: 0.8255 - val_loss: 0.3636 - val_accuracy: 0.8662
# Epoch 32/40
#
# Epoch 00032: val_loss improved from 0.35980 to 0.35925, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.4647 - accuracy: 0.8257 - val_loss: 0.3592 - val_accuracy: 0.8690
# Epoch 33/40
#
# Epoch 00033: val_loss did not improve from 0.35925
# 375/375 - 83s - loss: 0.4639 - accuracy: 0.8252 - val_loss: 0.3636 - val_accuracy: 0.8683
# Epoch 34/40
#
# Epoch 00034: val_loss did not improve from 0.35925
# 375/375 - 83s - loss: 0.4638 - accuracy: 0.8262 - val_loss: 0.3631 - val_accuracy: 0.8654
# Epoch 35/40
#
# Epoch 00035: val_loss improved from 0.35925 to 0.35456, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.4621 - accuracy: 0.8270 - val_loss: 0.3546 - val_accuracy: 0.8707
# Epoch 36/40
#
# Epoch 00036: val_loss did not improve from 0.35456
# 375/375 - 83s - loss: 0.4624 - accuracy: 0.8270 - val_loss: 0.3606 - val_accuracy: 0.8622
# Epoch 37/40
#
# Epoch 00037: val_loss did not improve from 0.35456
# 375/375 - 82s - loss: 0.4617 - accuracy: 0.8263 - val_loss: 0.3647 - val_accuracy: 0.8628
# Epoch 38/40
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00038: val_loss did not improve from 0.35456
# 375/375 - 83s - loss: 0.4597 - accuracy: 0.8273 - val_loss: 0.3589 - val_accuracy: 0.8639
# Epoch 39/40
#
# Epoch 00039: val_loss improved from 0.35456 to 0.35223, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.4531 - accuracy: 0.8295 - val_loss: 0.3522 - val_accuracy: 0.8703
# Epoch 40/40
#
# Epoch 00040: val_loss improved from 0.35223 to 0.35073, saving model to model_custom_base.h5
# 375/375 - 83s - loss: 0.4525 - accuracy: 0.8300 - val_loss: 0.3507 - val_accuracy: 0.8694

# %%
hist = pd.DataFrame(history.history)
hist.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy     lr
# 0  0.813573  0.701475  0.539866      0.802500  0.001
# 1  0.632767  0.762251  0.473700      0.825583  0.001
# 2  0.594196  0.776639  0.458654      0.819250  0.001
# 3  0.571363  0.785271  0.445362      0.830250  0.001
# 4  0.556464  0.790384  0.441228      0.828917  0.001

# %%
def plot(history):

  plt.subplot(2,1,1)
  plt.plot(history["loss"],marker='o',label="Training Loss")
  plt.plot(history['val_loss'],marker='o',label="Validation Loss")
  plt.xlabel("Epochs")
  plt.ylabel("Loss")
  plt.legend()
  
  plt.subplot(2,1,2)
  plt.plot(history["accuracy"],marker='o',label="Training Accuracy")
  plt.plot(history['val_accuracy'],marker='o',label="Validation Accuracy")
  plt.xlabel("Epochs")
  plt.ylabel("Accuracy")
  plt.legend()

  plt.tight_layout()

  plt.show()

# %%
plot(hist)

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print("Test loss: ", np.round(test_loss,2), " Test acc: ", np.round(test_acc*100,2))
# Out:
# Test loss:  0.36  Test acc:  86.37

# %%
predictions = model.predict(X_test)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
plt.figure(figsize=(20,20))
for idx in range(12):
  plt.subplot(4,3,idx+1)
  pred, true_label, img = predictions[idx], y_test[idx], X_test[idx,:,:,:]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(np.squeeze(img),cmap="gray")
  pred_label = np.argmax(pred)
  if pred_label == np.argmax(true_label):
    color="blue"
  else:
    color="red"
  plt.xlabel("{} {:2.0f}% ({})".format(pred_label, 100*np.max(pred),np.argmax(true_label),color=color))
