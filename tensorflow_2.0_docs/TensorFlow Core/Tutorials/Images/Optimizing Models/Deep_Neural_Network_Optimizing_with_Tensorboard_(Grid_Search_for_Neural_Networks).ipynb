# %% [markdown]
# <a href="https://colab.research.google.com/github/sourcecode369/TensorFlow-2.0/blob/master/tensorflow_2.0_docs/TensorFlow%20Core/Tutorials/Images/Optimizing%20Models/Deep_Neural_Network_Optimizing_with_Tensorboard_(Grid_Search_for_Neural_Networks).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
# %reload_ext tensorboard
import time

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D

# %%
#import util_mnist_reader
# X_train, y_train = util_mnist_reader.load_mnist("data/fashion/", kind='train')
# X_test, y_test = util_mnist_reader.load_mnist("data/fashion/", kind='t10k')


#comment down and uncomment above
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
x_train, x_test = X_train/255.0, X_test/255.0

x_train = x_train.reshape(x_train.shape + (1,))
x_test = x_test.reshape(x_test.shape + (1,))

# %%
import time
dense_layers = [0,1]
layer_sizes = [32,64]

# %%
histories = {}
for dense_layer in dense_layers:
    for layer_size in layer_sizes:
            model_ckeckpoint = tf.keras.callbacks.ModelCheckpoint(filepath="{}-nodes-{}-dense.h5".format(layer_size, dense_layer), monitor="val_loss",verbose=1,save_best_only=True, save_weights_only=True)
            model = Sequential()
            model.add(Dense(layer_size, input_shape = x_train.shape[1:]))
            model.add(Activation("relu"))
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation("relu"))
            model.add(Flatten())
            model.add(Dense(10))
            model.add(Activation(activation="softmax"))
            model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics = ["accuracy"])
            history = model.fit(x_train,y_train,batch_size=2048,validation_split=0.2,epochs=5, callbacks=[model_ckeckpoint])
            histories["{}-nodes-{}-dense".format(layer_size, dense_layer)] = history
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.0852 - acc: 0.6485
# Epoch 00001: val_loss improved from inf to 0.68627, saving model to 32-nodes-0-dense.h5
# 48000/48000 [==============================] - 2s 46us/sample - loss: 1.0779 - acc: 0.6507 - val_loss: 0.6863 - val_acc: 0.7631
# Epoch 2/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6230 - acc: 0.7904
# Epoch 00002: val_loss improved from 0.68627 to 0.55794, saving model to 32-nodes-0-dense.h5
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.6215 - acc: 0.7910 - val_loss: 0.5579 - val_acc: 0.8086
# Epoch 3/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5339 - acc: 0.8172
# Epoch 00003: val_loss improved from 0.55794 to 0.50816, saving model to 32-nodes-0-dense.h5
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.5334 - acc: 0.8176 - val_loss: 0.5082 - val_acc: 0.8224
# Epoch 4/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4934 - acc: 0.8309
# Epoch 00004: val_loss improved from 0.50816 to 0.48680, saving model to 32-nodes-0-dense.h5
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.4933 - acc: 0.8311 - val_loss: 0.4868 - val_acc: 0.8315
# Epoch 5/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4759 - acc: 0.8363
# Epoch 00005: val_loss improved from 0.48680 to 0.47126, saving model to 32-nodes-0-dense.h5
# 48000/48000 [==============================] - 2s 35us/sample - loss: 0.4756 - acc: 0.8365 - val_loss: 0.4713 - val_acc: 0.8358
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.0553 - acc: 0.6488
# Epoch 00001: val_loss improved from inf to 0.67053, saving model to 64-nodes-0-dense.h5
# 48000/48000 [==============================] - 3s 65us/sample - loss: 1.0488 - acc: 0.6510 - val_loss: 0.6705 - val_acc: 0.7700
# Epoch 2/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6070 - acc: 0.7969
# Epoch 00002: val_loss improved from 0.67053 to 0.55488, saving model to 64-nodes-0-dense.h5
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.6060 - acc: 0.7973 - val_loss: 0.5549 - val_acc: 0.8028
# Epoch 3/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5202 - acc: 0.8212
# Epoch 00003: val_loss improved from 0.55488 to 0.50921, saving model to 64-nodes-0-dense.h5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.5193 - acc: 0.8216 - val_loss: 0.5092 - val_acc: 0.8198
# Epoch 4/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4852 - acc: 0.8326
# Epoch 00004: val_loss improved from 0.50921 to 0.47493, saving model to 64-nodes-0-dense.h5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.4858 - acc: 0.8323 - val_loss: 0.4749 - val_acc: 0.8338
# Epoch 5/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4656 - acc: 0.8406
# Epoch 00005: val_loss improved from 0.47493 to 0.46284, saving model to 64-nodes-0-dense.h5
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.4648 - acc: 0.8408 - val_loss: 0.4628 - val_acc: 0.8372
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.1514 - acc: 0.6342
# Epoch 00001: val_loss improved from inf to 0.66684, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 73us/sample - loss: 1.1423 - acc: 0.6368 - val_loss: 0.6668 - val_acc: 0.7607
# Epoch 2/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.6031 - acc: 0.7911
# Epoch 00002: val_loss improved from 0.66684 to 0.53376, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.6015 - acc: 0.7917 - val_loss: 0.5338 - val_acc: 0.8109
# Epoch 3/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5083 - acc: 0.8241
# Epoch 00003: val_loss improved from 0.53376 to 0.48081, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.5082 - acc: 0.8241 - val_loss: 0.4808 - val_acc: 0.8322
# Epoch 4/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4644 - acc: 0.8400
# Epoch 00004: val_loss improved from 0.48081 to 0.45413, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.4634 - acc: 0.8404 - val_loss: 0.4541 - val_acc: 0.8412
# Epoch 5/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4393 - acc: 0.8482
# Epoch 00005: val_loss improved from 0.45413 to 0.43238, saving model to 32-nodes-1-dense.h5
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.4389 - acc: 0.8485 - val_loss: 0.4324 - val_acc: 0.8483
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 1.0321 - acc: 0.6550
# Epoch 00001: val_loss improved from inf to 0.59815, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 6s 119us/sample - loss: 1.0235 - acc: 0.6578 - val_loss: 0.5982 - val_acc: 0.7924
# Epoch 2/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.5448 - acc: 0.8132
# Epoch 00002: val_loss improved from 0.59815 to 0.49299, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 5s 107us/sample - loss: 0.5440 - acc: 0.8134 - val_loss: 0.4930 - val_acc: 0.8257
# Epoch 3/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4699 - acc: 0.8361
# Epoch 00003: val_loss improved from 0.49299 to 0.45241, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 5s 106us/sample - loss: 0.4702 - acc: 0.8359 - val_loss: 0.4524 - val_acc: 0.8416
# Epoch 4/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4319 - acc: 0.8505
# Epoch 00004: val_loss improved from 0.45241 to 0.42202, saving model to 64-nodes-1-dense.h5
# 48000/48000 [==============================] - 5s 107us/sample - loss: 0.4313 - acc: 0.8508 - val_loss: 0.4220 - val_acc: 0.8523
# Epoch 5/5
# 47104/48000 [============================>.] - ETA: 0s - loss: 0.4132 - acc: 0.8547
# Epoch 00005: val_loss did not improve from 0.42202
# 48000/48000 [==============================] - 5s 105us/sample - loss: 0.4124 - acc: 0.8550 - val_loss: 0.4272 - val_acc: 0.8471

# %%
def plot_histories(history, key):    
    plt.subplot(121)
    g = plt.plot(history.epoch, history.history["loss"], label=key, marker='o')
    plt.plot(history.epoch, history.history["val_loss"], "--", marker='o', c= g[0].get_color())
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.suptitle("Training and Validation Loss")
    plt.grid(True)
    plt.legend()

    plt.subplot(122)
    g = plt.plot(history.epoch, history.history["acc"], label=key, marker='o')
    plt.plot(history.epoch, history.history["val_acc"], "--", marker='o', c= g[0].get_color())
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.suptitle("Training and Validation Accuracy")
    plt.grid(True)
    plt.legend()

# %%
key = list(histories.keys())
plt.figure(figsize=(25,10))
for i in key:
    plot_histories(histories[i],i)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %% [markdown]
# #### Choosing the best model

# %%
max_val_accuracy = 0
model_name = None
for i in key:
    if histories[i].history["val_acc"][-1] > max_val_accuracy:
        max_val_acc = histories[i].history["val_acc"][-1]
        model_name = i

# %%
print(model_name)
# Out:
# 64-nodes-1-dense

# %%
model.load_weights(f"{model_name}.h5")

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0, batch_size=1024)

# %%
for name, value in zip(model.metrics_names, (loss, accuracy)):
    print(name, ":", value)
# Out:
# loss : 0.4474312471866608
# acc : 0.8415

# %%
pred = model.predict(x_test)

# %%
predictions = np.argmax(pred, axis=1)

# %%
print(f"The accuracy of the model is: {accuracy_score(predictions, y_test)*100}%")
# Out:
# The accuracy of the model is: 84.15%

# %%
print(classification_report(y_test, predictions, labels=np.arange(0,10)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      1000
#            1       0.97      0.95      0.96      1000
#            2       0.73      0.73      0.73      1000
#            3       0.85      0.86      0.85      1000
#            4       0.71      0.78      0.74      1000
#            5       0.93      0.93      0.93      1000
#            6       0.65      0.53      0.58      1000
#            7       0.91      0.91      0.91      1000
#            8       0.93      0.95      0.94      1000
#            9       0.93      0.94      0.93      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %%
plt.figure(figsize=(10,10))
cm = confusion_matrix(y_test, predictions)
sns.heatmap(cm, center=0, linewidth=1, fmt=".1f", annot=True,cmap="RdBu")

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel("{} {:2.0f}% ({})".format(labels[predicted_label],
                                100*np.max(predictions_array),
                                labels[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
labels = [ "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal",	"Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
num_rows = 4
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(20, 15))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, pred[i], y_test, x_test.reshape(-1, 28, 28))
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, pred[i], y_test)
plt.tight_layout()
plt.show()
